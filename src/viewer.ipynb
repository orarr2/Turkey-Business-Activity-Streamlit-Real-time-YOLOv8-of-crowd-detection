# %% [markdown]
# # Turkey Business Activity — Viewer notebook
#
# Run this end-to-end to analyze **your own** short YOLO sample from a public
# Turkey camera AND compare it live to the **cloud dashboard's 24-hour history**
# (pushed continuously by the admin's collector running on a GCP e2-micro).
#
# What you get, top-to-bottom:
#
# - Cells 1-6: pick a camera and verify the stream decodes.
# - Cell 7: 1-minute local footfall time series.
# - Cell 8: rolling z-score anomalies + peak-hour profile.
# - Cells 9-10: dwell-time tracking (prolonged stops).
# - Cells 11-14: appearance-based re-identification.
# - Cell 15: "is it worth opening a business here?" — footfall + dwell + consistency.
# - Cell 16: **the live cloud dashboard**, embedded inline, showing the admin's
#   cumulative 24-hour view. Compare your local minute-of-samples against the day.
# - Cells 17-18: rank multiple commercial sites; final summary.
#
# **You do NOT need any Firebase credentials to run this notebook.** The dashboard
# is public-read; the collector runs elsewhere.

# %% [markdown]
# ### Network reality
#
# The IBB streams (`livestream.ibb.gov.tr`) are public, but reachable only from an **open network** -
# your own machine, a VM, or a deployed app. Restricted sandboxes (incl. the environment that generated
# this repo) block those hosts via an allowlist. So **run this notebook locally**, where the streams resolve.

# %% [markdown]
# ## 0. Setup

# %%
# %pip install -q ultralytics opencv-python-headless yt-dlp pandas numpy matplotlib firebase-admin
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, time, datetime as dt
from collections import defaultdict
from pathlib import Path

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# make the shared app/ package importable from the notebook
sys.path.append(str(Path.cwd()))
from app.detect_core import load_model, detect_and_count, grab_frame, resolve_youtube, resolve_stream, VEHICLE_NAMES
from app.cameras import CAMERAS, active_cameras, GRID_CAMERAS

DATA_DIR = Path('data'); DATA_DIR.mkdir(exist_ok=True)
model = load_model('yolov8n.pt')
print('cameras available:', list(active_cameras()))
print('dashboard grid (4 live cameras):', GRID_CAMERAS)
# Out:
# cameras available: ['konya_hukumet', 'taksim', 'taksim_yeni', 'beyazit_meydan', 'kapali_carsi', 'misir_carsisi', 'sultanahmet_1', 'sultanahmet_1_yeni', 'kadikoy', 'eyup_sultan', 'uskudar', 'otogar_kavsagi', 'konya_kulturpark', 'konya_millet_caddesi', 'giresun_gazi']
# dashboard grid (4 live cameras): ['konya_hukumet', 'otogar_kavsagi', 'konya_kulturpark', 'konya_millet_caddesi']

# %% [markdown]
# ## 1. Pick a camera
#
# Verified high-footfall Turkey commercial cameras live in `app/cameras.py`. Grand Bazaar, Spice Bazaar,
# Taksim and Kadikoy are the densest commerce. The four cameras the live dashboard shows side by side
# (`GRID_CAMERAS`) are **Konya - Hukumet Meydani**, **Giresun - Gazi Caddesi**, **Otogar Kavsagi** and
# **Kadikoy**.
#
# `resolve_stream(cam)` turns any catalog entry into an openable HLS URL regardless of `kind`:
#
# - `hls` - used directly (IBB / tvkur).
# - `youtube` - resolved via yt-dlp.
# - `skyline` - Giresun: the tokenized `hd-auth.skylinewebcams.com` playlist, scraped from the page.
# - `webcamera24` - Otogar Kavsagi: the embedded tvkur/YouTube player on the webcamera24 page.
#
# The skyline and webcamera24 hosts only resolve from an **open network** (and rotate their tokens), so
# run this on your own machine; in a restricted sandbox they fail like the IBB hosts.

# %%
CAM_ID = 'konya_hukumet'   # works from any open network via tvkur. Other grid cams:
                           #   giresun_gazi (skylinewebcams), otogar_kavsagi (webcamera24), kadikoy (IBB)
                           # IBB cameras (taksim/kapali_carsi/...) may be geo-restricted to Turkey IPs.
cam = CAMERAS[CAM_ID]
stream_url = resolve_stream(cam)   # handles hls / youtube / skyline / webcamera24
print(cam['name'], '->', stream_url)
# Out:
# Konya - Hukumet Meydani / Sarraflar Yeralti Carsisi -> https://content.tvkur.com/l/c77i84vbb2nj4i0fr80g/master.m3u8

# %% [markdown]
# ## 2. Single-frame check
#
# Confirm the stream decodes and YOLO sees the crowd before collecting anything.

# %%
frame = grab_frame(stream_url)
if frame is None:
    print(f"WARN: {cam['name']} returned no frame (likely geo-blocked or stream down).")
    print('Try CAM_ID = \'konya_hukumet\' (tvkur, reachable everywhere) and re-run cell 1.')
else:
    print('frame shape:', frame.shape)
    print('counts:', detect_and_count(model, frame))

    res = model.predict(frame, conf=0.35, classes=[0,1,2,3,5,7], verbose=False)[0]
    plt.figure(figsize=(11, 6))
    plt.imshow(cv2.cvtColor(res.plot(), cv2.COLOR_BGR2RGB)); plt.axis('off')
    plt.title(cam['name']); plt.show()
# Out:
# frame shape: (1520, 2688, 3)
# counts: {'person': 1, 'bicycle': 0, 'car': 3, 'motorcycle': 0, 'bus': 0, 'truck': 0, 'vehicles': 3}

# %% [markdown]
# ## 3. Footfall time series (sparse sampling)
#
# For the **how much / when** question we don't need every frame - one sample every 15-30s is plenty and
# is gentle on the server. This is the same logic the collector runs continuously.

# %%
def footfall_series(stream_url, cam_name, interval_s=20, duration_min=1.0):
    rows, t_end = [], time.time() + duration_min * 60
    while time.time() < t_end:
        ts = dt.datetime.now(dt.timezone.utc)
        f = grab_frame(stream_url)
        c = detect_and_count(model, f) if f is not None else {'person': np.nan, 'vehicles': np.nan}
        rows.append({'ts': ts, 'cam': cam_name, 'person': c.get('person'), 'vehicles': c.get('vehicles')})
        print(f"[{ts:%H:%M:%S}] person={c.get('person')} vehicles={c.get('vehicles')}")
        time.sleep(interval_s)
    return pd.DataFrame(rows)

# Short live-collection run. Raise duration_min for longer studies, or just leave the
# collector daemon (`python -m app.collector`) running for genuine 24/7 data.
df = footfall_series(stream_url, cam['name'], interval_s=10, duration_min=1.0)
df.to_csv(DATA_DIR / f'footfall_{CAM_ID}.csv', index=False)
df.head()
# Out:
# [19:13:53] person=1 vehicles=2
# [19:14:05] person=0 vehicles=3
# [19:14:16] person=0 vehicles=3
# [19:14:27] person=0 vehicles=2
# [19:14:38] person=1 vehicles=1
# [19:14:50] person=0 vehicles=2
#                                 ts  \
# 0 2026-07-01 19:13:53.846313+00:00
# 1 2026-07-01 19:14:05.197274+00:00
# 2 2026-07-01 19:14:16.608720+00:00
# 3 2026-07-01 19:14:27.714369+00:00
# 4 2026-07-01 19:14:38.788114+00:00
#
#                                                  cam  person  vehicles
# 0  Konya - Hukumet Meydani / Sarraflar Yeralti Ca...       1         2
# 1  Konya - Hukumet Meydani / Sarraflar Yeralti Ca...       0         3
# 2  Konya - Hukumet Meydani / Sarraflar Yeralti Ca...       0         3
# 3  Konya - Hukumet Meydani / Sarraflar Yeralti Ca...       0         2
# 4  Konya - Hukumet Meydani / Sarraflar Yeralti Ca...       1         1

# %% [markdown]
# ## 4. Anomalies + peak-hour profile
#
# **Anomaly = rolling z-score > 2.5** on the footfall series: a sudden surge (event/promotion/protest) or an
# unusual drop (closure/weather). Peak-hour profile tells you *when* the commercial window is.

# %%
def flag_anomalies(s, window=12, z=2.5):
    mu = s.rolling(window, min_periods=4).mean()
    sd = s.rolling(window, min_periods=4).std().replace(0, np.nan)
    return ((s - mu) / sd).abs() > z

df['ts'] = pd.to_datetime(df['ts'])
df['anomaly'] = flag_anomalies(df['person'])

fig, ax = plt.subplots(1, 2, figsize=(15, 4))
ax[0].plot(df['ts'], df['person'], marker='o', label='people')
an = df[df['anomaly'] == True]
ax[0].scatter(an['ts'], an['person'], color='red', zorder=5, label='anomaly')
ax[0].set_title('Footfall over time'); ax[0].legend()

df['hour'] = df['ts'].dt.hour
df.groupby('hour')['person'].mean().plot(kind='bar', ax=ax[1])
ax[1].set_title('Avg people by hour (peak-hour profile)')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 5. Dwell-time / prolonged stops (tracking)
#
# "How long does a person or vehicle stay in front of the camera?" needs **object tracking** (stable IDs
# across frames), which only works on *consecutive* frames - so here we take a short **dense burst**
# (a few fps for ~60s) instead of sparse sampling. Ultralytics `model.track()` (ByteTrack) gives each
# object an id; we accumulate how many frames each id is seen and how little it moves.
#
# - **Long dwell + low movement** = lingering: window-shopping / a queue / a parked vehicle.
# - High share of *lingering* people is a strong **commercial-quality** signal (people stop, not just pass).

# %%
from app.detect_core import iter_frames, NAME_BY_ID

def dwell_analysis(stream_url, seconds=30, target_fps=3, conf=0.35):
    """Dense burst with tracking. Returns per-track dwell seconds + movement.

    iter_frames handles header-required hosts (tvkur, IBB, skylinewebcams) by
    downloading the latest segments with the right Referer/Origin and decoding
    locally, since cv2.VideoCapture(url) can't pass headers on Windows.
    """
    frames_seen = defaultdict(int)
    centroids = defaultdict(list)
    track_cls = {}
    n_frames = int(seconds * target_fps)
    for frame in iter_frames(stream_url, max_frames=n_frames):
        r = model.track(frame, persist=True, conf=conf, classes=[0,2,3,5,7],
                        tracker='bytetrack.yaml', verbose=False)[0]
        if r.boxes.id is not None:
            for box, tid, cl in zip(r.boxes.xywh.cpu().numpy(),
                                    r.boxes.id.int().cpu().tolist(),
                                    r.boxes.cls.int().cpu().tolist()):
                frames_seen[tid] += 1
                centroids[tid].append((float(box[0]), float(box[1])))
                track_cls[tid] = cl

    rows = []
    for tid, n in frames_seen.items():
        pts = np.array(centroids[tid])
        movement = float(np.linalg.norm(pts.max(0) - pts.min(0))) if len(pts) > 1 else 0.0
        rows.append({'track_id': tid,
                     'class': NAME_BY_ID.get(track_cls[tid], str(track_cls[tid])),
                     'dwell_s': round(n / target_fps, 1),
                     'movement_px': round(movement, 1)})
    return pd.DataFrame(rows).sort_values('dwell_s', ascending=False) if rows else pd.DataFrame(
        columns=['track_id','class','dwell_s','movement_px'])

dwell = dwell_analysis(stream_url, seconds=30, target_fps=3, conf=0.25)
dwell.head(15)
# Out:
#     track_id   class  dwell_s  movement_px
# 1          2  person     17.7        164.0
# 6          8  person     17.0        100.4
# 0          1  person     16.0         92.6
# 4          5     car     15.7         36.3
# 7         14     car     15.7         46.9
# 9         16     car     13.3         32.8
# 5          6   truck     11.0         82.1
# 8         15     car      9.0         16.8
# 10        30  person      5.0         32.7
# 2          3     car      2.3         17.3
# 11        42     car      1.7          5.8
# 12        48     car      1.7         12.9
# 3          4  person      1.0         31.0

# %%
# Flag prolonged stationary objects: long dwell AND little movement.
PERSON_DWELL_S, VEHICLE_DWELL_S, MAX_MOVE_PX = 25, 40, 60
if not dwell.empty:
    is_person = dwell['class'] == 'person'
    stationary = dwell[((is_person & (dwell['dwell_s'] >= PERSON_DWELL_S)) |
                        (~is_person & (dwell['dwell_s'] >= VEHICLE_DWELL_S)))
                       & (dwell['movement_px'] <= MAX_MOVE_PX)]
    print(f"Prolonged stops detected: {len(stationary)}")
    display(stationary)
    linger_rate = (is_person & (dwell['dwell_s'] >= PERSON_DWELL_S)).sum() / max(1, is_person.sum())
    print(f"Linger rate (people who stayed >= {PERSON_DWELL_S}s): {linger_rate:.0%}")
# Out:
# Prolonged stops detected: 0
# Empty DataFrame
# Columns: [track_id, class, dwell_s, movement_px]
# Index: []
# Linger rate (people who stayed >= 25s): 0%

# %% [markdown]
# ## 5b. Re-identification - "have I seen this person before?"
#
# The detection counts above tell you *how many* people are visible at any moment, but they
# double-count anyone who lingers in front of the camera. To answer questions like *"how many
# unique customers walked by today?"* or *"is that the same delivery van I saw yesterday?"*
# we need **re-identification**: a persistent identity attached to each person/vehicle that
# survives across frames, bursts and days.
#
# The implementation is in `app/reid.py`:
#
# 1. For each YOLO detection, crop the bounding box.
# 2. Build a *masked* HSV color histogram (8x8x8 bins, V<30 pixels ignored - kills the
#    sodium-yellow night cast on the Konya square) plus aspect ratio + normalized area.
# 3. L2-normalize -> 514-dim appearance vector.
# 4. Compare to every entity of the same class already in `data/reid.db` via cosine
#    similarity. If the best match is >= `threshold` (default 0.92) we update its
#    `sightings` and `last_seen`; otherwise we register a new entity.
#
# This is a **demo-grade signature**. It works well in daylight (different clothing colors
# give clearly different histograms). It produces false matches at night when the whole
# scene is yellow-tinted - swap `embed_crop()` for an OSNet/torchreid forward pass for
# production-grade re-ID; the SQLite registry around it stays the same.

# %%
from app.detect_core import load_model, grab_frame, detect_with_boxes, annotate
from app.reid import ReidStore
import cv2, time
import matplotlib.pyplot as plt

REID_DB = 'data/reid_notebook.db'
Path(REID_DB).parent.mkdir(parents=True, exist_ok=True)

# If we're re-running the notebook (the kernel is alive), the previous ReidStore is
# still holding a SQLite connection to REID_DB. Close it before we try to delete
# the file, otherwise Windows returns PermissionError [WinError 32].
try:
    reid.close()         # noqa: F821  (reid is defined by a prior run of this cell)
except NameError:
    pass

# Fresh registry for the demo so re-runs are reproducible. If something else
# still holds the file (orphan kernel, antivirus scan), we keep the existing
# rows instead of crashing - re-identification just continues with what's there.
try:
    Path(REID_DB).unlink(missing_ok=True)
    print('reid_notebook.db cleared - fresh demo registry')
except PermissionError:
    print('reid_notebook.db is locked by another process - keeping existing rows. '
          'New entities will be merged into the existing registry; this is fine '
          'for the demo, just not a clean-room run.')

reid = ReidStore(REID_DB, threshold=0.92)

# Use the model we already loaded above; lower conf so we catch the small/distant
# people the Konya wide-angle camera shows.
CAM_ID = 'konya_hukumet'
cam = CAMERAS[CAM_ID]
stream_url = cam['url']
print('feeding re-ID from', cam['name'])
# Out:
# reid_notebook.db cleared - fresh demo registry
# feeding re-ID from Konya - Hukumet Meydani / Sarraflar Yeralti Carsisi

# %%
# Sample N frames every `interval_s` seconds, run YOLO on each, push every detection
# through the re-ID registry. Short loop here so the notebook completes; the collector
# daemon does the real long-running version.
N_SAMPLES, INTERVAL_S, CONF = 8, 5, 0.25

rows = []
for i in range(N_SAMPLES):
    f = grab_frame(stream_url)
    if f is None:
        print(f'[{i:02d}] miss'); time.sleep(INTERVAL_S); continue
    counts, boxes = detect_with_boxes(model, f, conf=CONF)
    results = reid.update_from_frame(CAM_ID, f, boxes)
    new = sum(r.is_new for r in results)
    seen_again = len(results) - new
    rows.append({'sample': i, 'person': counts['person'], 'vehicles': counts['vehicles'],
                 'detections': len(boxes), 'new_ids': new, 'seen_again': seen_again})
    print(f'[{i:02d}] person={counts["person"]} vehicles={counts["vehicles"]} '
          f'-> new={new} seen_again={seen_again}')
    time.sleep(INTERVAL_S)

reid_df = pd.DataFrame(rows)
reid_df
# Out:
# [00] person=0 vehicles=2 -> new=2 seen_again=0
# [01] person=1 vehicles=3 -> new=4 seen_again=0
# [02] person=1 vehicles=2 -> new=3 seen_again=0
# [03] person=0 vehicles=2 -> new=2 seen_again=0
# [04] person=0 vehicles=3 -> new=2 seen_again=1
# [05] person=0 vehicles=3 -> new=1 seen_again=2
# [06] person=0 vehicles=2 -> new=2 seen_again=0
# [07] person=0 vehicles=3 -> new=3 seen_again=0
#    sample  person  vehicles  detections  new_ids  seen_again
# 0       0       0         2           2        2           0
# 1       1       1         3           4        4           0
# 2       2       1         2           3        3           0
# 3       3       0         2           2        2           0
# 4       4       0         3           3        2           1
# 5       5       0         3           3        1           2
# 6       6       0         2           2        2           0
# 7       7       0         3           3        3           0

# %%
# Roll-up: how many unique entities did we see? how many came back >=3 times?
stats = reid.stats(CAM_ID)
print('Total unique entities (this camera):', stats['total_unique'])
print('Total sightings:', stats['total_sightings'])
for cls, s in stats['per_class'].items():
    print(f"  {cls:10s}  unique={s['unique']}  sightings={s['total_sightings']}  "
          f"regulars(>=3)={s['regulars']}")

print('\nTop returning entities:')
for r in reid.top_regulars(CAM_ID, n=10):
    print(f"  #{r['entity_id']:4d}  {r['cls']:8s}  sightings={r['sightings']}  "
          f"first={r['first_seen']}  last={r['last_seen']}")
# Out:
# Total unique entities (this camera): 19
# Total sightings: 22
#   car         unique=14  sightings=17  regulars(>=3)=1
#   person      unique=2  sightings=2  regulars(>=3)=0
#   truck       unique=3  sightings=3  regulars(>=3)=0
#
# Top returning entities:
#   #   7  car       sightings=3  first=2026-07-01T19:15:48Z  last=2026-07-01T19:16:07Z
#   #  13  car       sightings=2  first=2026-07-01T19:16:01Z  last=2026-07-01T19:16:07Z
#   #   2  car       sightings=1  first=2026-07-01T19:15:34Z  last=2026-07-01T19:15:34Z
#   #   5  car       sightings=1  first=2026-07-01T19:15:41Z  last=2026-07-01T19:15:41Z
#   #   6  car       sightings=1  first=2026-07-01T19:15:41Z  last=2026-07-01T19:15:41Z
#   #   8  car       sightings=1  first=2026-07-01T19:15:48Z  last=2026-07-01T19:15:48Z
#   #  10  car       sightings=1  first=2026-07-01T19:15:54Z  last=2026-07-01T19:15:54Z
#   #  11  car       sightings=1  first=2026-07-01T19:15:54Z  last=2026-07-01T19:15:54Z
#   #  12  car       sightings=1  first=2026-07-01T19:16:01Z  last=2026-07-01T19:16:01Z
#   #  14  car       sightings=1  first=2026-07-01T19:16:07Z  last=2026-07-01T19:16:07Z

# %%
# Visual: returning-visitor curve - what fraction of detections are 'seen again' over time?
if len(reid_df) >= 3:
    reid_df = reid_df.copy()
    reid_df['returning_rate'] = (reid_df['seen_again'] /
                                 reid_df['detections'].replace(0, np.nan))
    fig, ax = plt.subplots(1, 2, figsize=(13, 4))
    ax[0].plot(reid_df['sample'], reid_df['new_ids'], marker='o', label='new IDs')
    ax[0].plot(reid_df['sample'], reid_df['seen_again'], marker='s', label='seen again')
    ax[0].set_title('Re-ID activity per sample')
    ax[0].set_xlabel('sample #'); ax[0].set_ylabel('count'); ax[0].legend()

    ax[1].plot(reid_df['sample'], reid_df['returning_rate'].fillna(0), marker='o',
               color='#36d399')
    ax[1].set_title('Returning-visitor rate (seen_again / detections)')
    ax[1].set_xlabel('sample #'); ax[1].set_ylim(0, 1)
    plt.tight_layout(); plt.show()
else:
    print('Not enough samples for the returning-visitor plot.')

# %% [markdown]
# IMPORTANT - re-ID quality depends on the scene.
# #
# At Konya Hukumet Meydani at night the whole scene is uniform sodium yellow.
# Color-histogram re-ID will over-merge IDs there. To validate the *concept*, point
# the camera at the daylight Grand Bazaar / Spice Bazaar (different clothing colors)
# or set `threshold=0.97` to be very conservative about matches.
# #
# Production path:
#   pip install torchreid
#   from torchreid.utils import FeatureExtractor
#   extractor = FeatureExtractor(model_name='osnet_ain_x1_0', model_path='', device='cpu')
#   def embed_crop(crop, cls): return extractor([crop])[0].cpu().numpy()
# Then keep the rest of app/reid.py exactly as-is. The 2,048-dim OSNet embedding
# survives lighting changes, pose changes, and partial occlusion much better than
# a color histogram.

# %% [markdown]
# ## 6. "Is it worth opening a business here?" - a simple score
#
# Combine three signals into one 0-100 score. Tune the weights to your business type (a cafe wants high
# *linger*; a kiosk wants high *throughput*).
#
# - **Volume** - median footfall (raw demand).
# - **Linger** - share of people who stop (engagement / conversion potential).
# - **Consistency** - low coefficient of variation (steady traffic beats spiky).

# %%
def business_score(footfall_df, dwell_df, w=(0.5, 0.3, 0.2)):
    people = footfall_df['person'].dropna()
    volume = float(people.median()) if len(people) else 0.0
    cv = float(people.std() / people.mean()) if people.mean() else 1.0
    consistency = max(0.0, 1 - cv)
    is_p = dwell_df['class'] == 'person'
    linger = float((is_p & (dwell_df['dwell_s'] >= 25)).sum() / max(1, is_p.sum())) if len(dwell_df) else 0.0
    vol_norm = min(1.0, volume / 40.0)  # ~40 people/frame treated as 'very busy'; tune per camera FOV
    score = 100 * (w[0]*vol_norm + w[1]*linger + w[2]*consistency)
    return {'volume_median': round(volume,1), 'linger_rate': round(linger,2),
            'consistency': round(consistency,2), 'score_0_100': round(score,1)}

print(cam['name'])
business_score(df, dwell)
# Out:
# Konya - Hukumet Meydani / Sarraflar Yeralti Carsisi
# {'volume_median': 0.0,
#  'linger_rate': 0.0,
#  'consistency': 0.0,
#  'score_0_100': 0.0}

# %% [markdown]
# ## 7. Compare with the live cloud dashboard
#
# The rest of this notebook was your **local** analysis — a minute of sampling on
# one camera. The cloud collector has been running non-stop on a GCP VM,
# accumulating 4 cameras × 24 hours into Firestore, and the HTML dashboard below
# subscribes to that. Comparing the two answers real questions:
#
# - Is the moment I sampled representative of the whole day? (my minute vs the 24h chart)
# - Am I hitting a peak, a valley, or the average?
# - Did any anomaly fire in the last 24 hours that I missed by sampling now?
#
# Nothing here writes to Firestore — it's a plain HTML page that reads from it.

# %%
# Serve web/ locally on http://localhost:8000 and embed the live dashboard.
# The dashboard reads directly from Firestore (public-read) — no credentials
# needed. The tvkur HLS proxy lets the Konya tiles autoplay.
import sys, threading, http.server, webbrowser
from app.dashboard_server import DashboardHandler, WEB_DIR, port_is_free

DASHBOARD_PORT = 8000
_main = sys.modules['__main__']

if getattr(_main, '_dash_server', None) is None:
    if not port_is_free(DASHBOARD_PORT):
        print(f'Port {DASHBOARD_PORT} already in use — assuming a dashboard is up. '
              f'Open http://localhost:{DASHBOARD_PORT}/')
        _main._dash_server = 'external'
    else:
        factory = lambda *a, **k: DashboardHandler(*a, directory=str(WEB_DIR), **k)
        http.server.ThreadingHTTPServer.allow_reuse_address = True
        http.server.ThreadingHTTPServer.daemon_threads      = True
        srv = http.server.ThreadingHTTPServer(('', DASHBOARD_PORT), factory)
        threading.Thread(target=srv.serve_forever, daemon=True).start()
        _main._dash_server = srv
        print(f'Dashboard server started at http://localhost:{DASHBOARD_PORT}/')

dash_url = f'http://localhost:{DASHBOARD_PORT}/'
if not getattr(_main, '_dash_browser_opened', False):
    try:    webbrowser.open(dash_url, new=2)
    except: pass
    _main._dash_browser_opened = True

from IPython.display import display, HTML, IFrame
display(HTML(f'<p><b>Live dashboard (cloud collector, 24h TTL):</b> '
             f'<a href="{dash_url}" target="_blank">{dash_url}</a></p>'))
display(IFrame(dash_url, width='100%', height=640))
# Out:
# Dashboard server started at http://localhost:8000/
# <p><b>Live dashboard (cloud collector, 24h TTL):</b> <a href="http://localhost:8000/" target="_blank">http://localhost:8000/</a></p>
#         <iframe
#             width="100%"
#             height="640"
#             src="http://localhost:8000/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#   "GET / HTTP/1.1" 200 -
#   "GET /firebase-config.js?v=15 HTTP/1.1" 200 -
#   "GET /cameras.js?v=15 HTTP/1.1" 200 -
#   "GET /app.js?v=15 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/265-1782933500.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9988-1782933492.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7293-1782933500.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/313-1782933499.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/266-1782933502.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9989-1782933494.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7294-1782933502.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/314-1782933501.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9990-1782933496.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9991-1782933499.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9992-1782933501.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7295-1782933504.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/315-1782933503.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/267-1782933504.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9993-1782933503.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7296-1782933506.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/268-1782933506.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9994-1782933505.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/316-1782933505.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/317-1782933507.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/318-1782933509.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9995-1782933508.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7297-1782933508.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/269-1782933508.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9996-1782933510.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/270-1782933510.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7298-1782933510.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9997-1782933512.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/271-1782933512.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/319-1782933511.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7299-1782933512.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/320-1782933513.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7300-1782933514.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/272-1782933514.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9998-1782933514.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7301-1782933516.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/321-1782933515.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/273-1782933516.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/9999-1782933516.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/322-1782933517.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7302-1782933518.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7303-1782933520.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/330-1782933533.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/280-1782933530.ts HTTP/1.1" 502 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7306-1782933526.ts HTTP/1.1" 502 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10006-1782933532.ts HTTP/1.1" 200 -
#   "GET / HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/331-1782933535.ts HTTP/1.1" 200 -
#   "GET /firebase-config.js?v=15 HTTP/1.1" 200 -
#   "GET /cameras.js?v=15 HTTP/1.1" 200 -
#   "GET /app.js?v=15 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10007-1782933534.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/332-1782933537.ts HTTP/1.1" 200 -
#   code 404, message File not found
#   "GET /favicon.ico HTTP/1.1" 404 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7335-1782933588.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/282-1782933534.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7309-1782933532.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/309-1782933588.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10031-1782933587.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/359-1782933591.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/333-1782933539.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/283-1782933536.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7310-1782933534.ts HTTP/1.1" 502 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/310-1782933590.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7336-1782933590.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10032-1782933590.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/360-1782933593.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/334-1782933541.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/284-1782933538.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7310-1782933534.ts HTTP/1.1" 502 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/285-1782933540.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10033-1782933592.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/361-1782933595.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/311-1782933592.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/286-1782933542.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10034-1782933594.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/312-1782933594.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/287-1782933544.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7337-1782933592.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7312-1782933538.ts HTTP/1.1" 502 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10035-1782933596.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/313-1782933596.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7338-1782933594.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/362-1782933597.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10036-1782933599.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7339-1782933596.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/363-1782933599.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10037-1782933601.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/314-1782933598.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7340-1782933598.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/315-1782933600.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7341-1782933600.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/364-1782933601.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/365-1782933603.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7342-1782933602.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10038-1782933603.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/316-1782933602.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7343-1782933604.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/317-1782933604.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/366-1782933605.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/367-1782933607.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7344-1782933606.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10039-1782933605.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/318-1782933606.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/319-1782933608.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7345-1782933608.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10040-1782933608.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/368-1782933609.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7346-1782933610.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/320-1782933610.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10041-1782933610.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/369-1782933611.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7347-1782933612.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/321-1782933612.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10042-1782933612.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/370-1782933613.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7348-1782933614.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10043-1782933614.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/322-1782933614.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/371-1782933615.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10044-1782933616.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/323-1782933616.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/372-1782933617.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7349-1782933616.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7350-1782933618.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/324-1782933618.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10045-1782933619.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/325-1782933620.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/373-1782933619.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10046-1782933621.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/374-1782933621.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7351-1782933620.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/326-1782933622.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/375-1782933623.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7352-1782933622.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10047-1782933623.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/327-1782933624.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7353-1782933624.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/328-1782933626.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7354-1782933626.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/376-1782933625.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10048-1782933625.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/329-1782933628.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/377-1782933627.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10049-1782933627.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7355-1782933628.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/378-1782933629.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/330-1782933630.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10050-1782933630.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7356-1782933630.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/379-1782933631.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10051-1782933632.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7357-1782933632.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/331-1782933632.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7358-1782933634.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/380-1782933633.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10052-1782933634.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/332-1782933634.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/381-1782933635.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7359-1782933636.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/333-1782933636.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/382-1782933637.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10053-1782933636.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/334-1782933638.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10054-1782933639.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7360-1782933638.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7361-1782933640.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10055-1782933641.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/335-1782933640.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/383-1782933639.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10056-1782933643.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/336-1782933642.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7362-1782933642.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/384-1782933641.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10057-1782933645.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7363-1782933644.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/385-1782933643.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/337-1782933644.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/386-1782933645.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7364-1782933646.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/338-1782933646.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/387-1782933647.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10058-1782933647.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7365-1782933648.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/339-1782933648.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/388-1782933649.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7366-1782933650.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/340-1782933650.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/389-1782933651.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/341-1782933652.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7367-1782933652.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/342-1782933654.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7368-1782933654.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/343-1782933656.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7369-1782933656.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/344-1782933660.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7370-1782933658.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10059-1782933650.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/390-1782933653.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7371-1782933660.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/391-1782933655.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/345-1782933662.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10060-1782933652.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7372-1782933662.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/392-1782933657.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/346-1782933664.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10061-1782933654.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7373-1782933664.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/393-1782933659.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/347-1782933666.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10062-1782933656.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7374-1782933666.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/394-1782933661.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/348-1782933668.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10063-1782933659.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7375-1782933668.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/395-1782933663.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/349-1782933670.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10064-1782933661.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7376-1782933670.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/396-1782933665.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/350-1782933672.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7377-1782933672.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10065-1782933663.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/397-1782933667.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/351-1782933675.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7378-1782933674.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10066-1782933665.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/398-1782933669.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/352-1782933677.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7379-1782933676.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10067-1782933667.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/399-1782933671.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/353-1782933679.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7380-1782933678.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10068-1782933670.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/400-1782933673.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/354-1782933681.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7381-1782933680.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/401-1782933675.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/355-1782933683.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10069-1782933672.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7382-1782933682.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/402-1782933677.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/356-1782933685.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10070-1782933674.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7383-1782933684.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/403-1782933679.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/357-1782933687.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10071-1782933676.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7384-1782933686.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/404-1782933681.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/358-1782933689.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10072-1782933678.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7385-1782933688.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/405-1782933683.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/359-1782933691.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7386-1782933690.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10073-1782933681.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/360-1782933695.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/406-1782933685.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7387-1782933692.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10074-1782933683.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/407-1782933687.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7388-1782933694.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10075-1782933685.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/361-1782933697.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/408-1782933689.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7389-1782933696.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10076-1782933687.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/362-1782933699.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/409-1782933691.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7390-1782933698.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10077-1782933690.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/363-1782933700.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/410-1782933693.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7391-1782933700.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/364-1782933703.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/411-1782933695.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10078-1782933692.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7392-1782933702.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/365-1782933705.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/412-1782933697.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10079-1782933694.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7393-1782933704.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/366-1782933706.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/413-1782933699.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10080-1782933696.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7394-1782933706.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/367-1782933708.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/414-1782933701.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10081-1782933699.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7395-1782933708.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/368-1782933711.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/415-1782933703.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10082-1782933701.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7396-1782933710.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/369-1782933712.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/416-1782933705.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
# ...
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7414-1782933746.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/433-1782933740.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/387-1782933749.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7393-1782933704.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7394-1782933706.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7395-1782933708.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7396-1782933710.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/458-1782933790.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10121-1782933787.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7435-1782933788.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/408-1782933791.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/459-1782933792.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10122-1782933790.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7436-1782933790.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/409-1782933793.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/460-1782933794.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7437-1782933792.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10123-1782933792.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/410-1782933795.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/461-1782933796.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7438-1782933794.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10124-1782933794.ts HTTP/1.1" 502 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/411-1782933797.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/462-1782933798.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7439-1782933796.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10125-1782933796.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/412-1782933799.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10126-1782933799.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/463-1782933800.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7440-1782933798.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10127-1782933801.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/413-1782933801.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/464-1782933802.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7441-1782933800.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/414-1782933803.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/465-1782933804.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7442-1782933802.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/415-1782933805.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/466-1782933806.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10128-1782933803.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7443-1782933804.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10129-1782933805.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/416-1782933807.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/467-1782933808.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10130-1782933807.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7444-1782933806.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/417-1782933809.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/468-1782933810.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10131-1782933810.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7445-1782933808.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/418-1782933811.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/469-1782933812.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/10132-1782933812.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/7446-1782933810.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/419-1782933813.ts HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i6hb84cnrb6mlji3g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i9cfbb2nj4i0fr82g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i91vbb2nj4i0fr81g/master.m3u8 HTTP/1.1" 200 -
#   "GET /tvkur/c77i84vbb2nj4i0fr80g/master.m3u8 HTTP/1.1" 200 -

# %% [markdown]
# ## 8. Compare multiple commercial sites
#
# Loop the footfall sampler over several cameras to rank locations by activity - the input to a
# site-selection decision.

# %%
# Rank the four dashboard cameras (plus the bazaars) by activity. Each camera is
# tested briefly; cameras that can't be resolved or return no frames are skipped.
seen = set(); SITES = []
for cid in GRID_CAMERAS + ['kapali_carsi', 'misir_carsisi']:
    if cid not in seen:
        seen.add(cid); SITES.append(cid)

summary = []
for cid in SITES:
    c = CAMERAS.get(cid)
    if not c or not c.get('url'):
        print(f'{cid}: skipped (not in catalog or no url)')
        continue
    try:
        url = resolve_stream(c)
    except Exception as e:
        print(f'{cid}: resolve failed ({e})')
        continue
    # one quick decode check before spending 30s on this camera
    if grab_frame(url) is None:
        print(f'{cid}: no frame from stream (geo-blocked / down). Skipping.')
        continue
    sdf = footfall_series(url, c['name'], interval_s=10, duration_min=0.5)
    summary.append({'site': c['name'],
                    'median_people': sdf['person'].median(),
                    'max_people': sdf['person'].max()})

pd.DataFrame(summary).sort_values('median_people', ascending=False)
# Out:
# [19:16:29] person=1 vehicles=0
# [19:16:40] person=1 vehicles=2
# [19:16:52] person=1 vehicles=2
# [19:17:05] person=0 vehicles=1
# [19:17:17] person=1 vehicles=1
# [19:17:29] person=0 vehicles=0
# [19:17:41] person=2 vehicles=0
# [19:17:52] person=0 vehicles=0
# [19:18:04] person=0 vehicles=0
# [19:18:16] person=0 vehicles=1
# [19:18:28] person=0 vehicles=1
# [19:18:39] person=0 vehicles=1
# kapali_carsi: no frame from stream (geo-blocked / down). Skipping.
# misir_carsisi: no frame from stream (geo-blocked / down). Skipping.
#                                                 site  median_people  \
# 0  Konya - Hukumet Meydani / Sarraflar Yeralti Ca...            1.0
# 1                                     Otogar Kavsagi            0.0
# 2                                 Konya - Kulturpark            0.0
# 3           Konya - Millet Caddesi / Hastane Kavsagi            0.0
#
#    max_people
# 0           1
# 1           1
# 2           2
# 3           0

# %% [markdown]
# ## 9. Live summary - what did we find?
#
# Pulls everything the notebook saw on this run into a single block: the anomalies
# flagged across every sampled camera, the re-ID totals, and a tiny visualisation
# plotting all anomalies on the same timeline. Re-running the notebook regenerates
# this from scratch - no stale timestamps from someone else's session leak through.

# %%
try:
    import pandas as pd
    import matplotlib.pyplot as plt
    from datetime import datetime, timezone

    print(f"Notebook run finished at {datetime.now(timezone.utc).strftime('%Y-%m-%d %H:%M:%S')} UTC")
    print(f"Live camera for this run: {cam['name']}")
    print("=" * 78)

    # ---- aggregate anomalies into one DataFrame ----
    anom_frames = []
    if "df" in dir() and isinstance(df, pd.DataFrame) and not df.empty and "anomaly" in df.columns:
        a = df[df["anomaly"] == True].copy()
        if not a.empty:
            a["cam"] = cam["name"]
            anom_frames.append(a[["ts", "cam", "person", "vehicles"]])
    anom = pd.concat(anom_frames, ignore_index=True) if anom_frames else \
           pd.DataFrame(columns=["ts", "cam", "person", "vehicles"])

    if len(anom):
        print(f"\nAnomalies flagged (rolling z > 2.5): {len(anom)}")
        print(anom.to_string(index=False))
    else:
        print("\nAnomalies flagged: 0")
        print("(Too few samples for the z-score window to trip, or the scene was steady.)")

    # ---- re-ID rollup ----
    if "reid" in dir():
        stats = reid.stats(CAM_ID)
        print("\n" + "-" * 78)
        print(f"Re-identification - {cam['name']}")
        print(f"  total unique entities   : {stats['total_unique']}")
        print(f"  total sightings         : {stats['total_sightings']}")
        for cls, s in stats["per_class"].items():
            print(f"    {cls:10s}  unique={s['unique']}  "
                  f"sightings={s['total_sightings']}  "
                  f"regulars(>=3)={s['regulars']}")
        regulars = reid.top_regulars(CAM_ID, n=5)
        if regulars:
            print("  top returning:")
            for r in regulars:
                print(f"    #{r['entity_id']:>4}  {r['cls']:8s}  "
                      f"sightings={r['sightings']}  last_seen={r['last_seen']}")

    # ---- always-on visual: footfall over this run + anomalies overlaid ----
    # Build the plot only when we have data; do NOT call ax.legend() on an empty
    # axes (that produces the "No artists with labels found" warning).
    if "df" in dir() and isinstance(df, pd.DataFrame) and not df.empty:
        ts = pd.to_datetime(df["ts"])
        fig, ax = plt.subplots(figsize=(12, 3.5))
        ax.plot(ts, df["person"],   marker="o", color="#4f8cff", label="people")
        ax.plot(ts, df["vehicles"], marker="s", color="#f0a35e", label="vehicles", alpha=0.85)
        if len(anom):
            ax.scatter(pd.to_datetime(anom["ts"]), anom["person"],
                       s=160, color="#ef4444", marker="X", zorder=5, label="anomaly")
        ax.set_title(f"This run: {cam['name']}  ({len(df)} samples, {len(anom)} anomalies)")
        ax.set_ylabel("count per frame"); ax.set_xlabel("timestamp (UTC)")
        ax.legend(loc="upper left"); ax.grid(alpha=0.3)
        plt.tight_layout(); plt.show()

    print("\n" + "=" * 78)
    print("For the persistent shared HTML dashboard (Firestore-backed):")
    print("  collector  : run the cell in Section 7 of this notebook,")
    print("               or `python -m app.collector --interval 20 --only "
          "konya_hukumet,otogar_kavsagi,konya_kulturpark,konya_millet_caddesi`")
    print("  dashboard  : python serve.py        (from the project root)")
    print("  open       : http://localhost:8000  (opens automatically)")

except Exception as e:
    print(f"summary cell stopped early: {type(e).__name__}: {e}")
# Out:
# Notebook run finished at 2026-07-01 19:18:54 UTC
# Live camera for this run: Konya - Hukumet Meydani / Sarraflar Yeralti Carsisi
# ==============================================================================
#
# Anomalies flagged: 0
# (Too few samples for the z-score window to trip, or the scene was steady.)
#
# ------------------------------------------------------------------------------
# Re-identification - Konya - Hukumet Meydani / Sarraflar Yeralti Carsisi
#   total unique entities   : 19
#   total sightings         : 22
#     car         unique=14  sightings=17  regulars(>=3)=1
#     person      unique=2  sightings=2  regulars(>=3)=0
#     truck       unique=3  sightings=3  regulars(>=3)=0
#   top returning:
#     #   7  car       sightings=3  last_seen=2026-07-01T19:16:07Z
#     #  13  car       sightings=2  last_seen=2026-07-01T19:16:07Z
#     #   2  car       sightings=1  last_seen=2026-07-01T19:15:34Z
#     #   5  car       sightings=1  last_seen=2026-07-01T19:15:41Z
#     #   6  car       sightings=1  last_seen=2026-07-01T19:15:41Z
# ==============================================================================
# For the persistent shared HTML dashboard (Firestore-backed):
#   collector  : run the cell in Section 7 of this notebook,
#                or `python -m app.collector --interval 20 --only konya_hukumet,otogar_kavsagi,konya_kulturpark,konya_millet_caddesi`
#   dashboard  : python serve.py        (from the project root)
#   open       : http://localhost:8000  (opens automatically)
